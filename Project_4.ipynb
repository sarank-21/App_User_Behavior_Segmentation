# %% [markdown]
# # **App User Behavior Segmentation Using Unsupervised Machine Learning**

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# %% [markdown]
# ## **1. Data Collection**

# %%
app_df = pd.read_csv(r"D:\PROJECTS\Capstone_Project_4\App_User_Behavior_Segmentation\app_user_behavior_dataset.csv")

# %%
app_df.info()

# %%
app_df.duplicated().sum()

# %%
app_df['rating_given'].isnull().mean()*100

# %%
app_df['rating_given'].median()

# %%
app_df['rating_given'].fillna(app_df['rating_given'].median(),inplace=True)

# %% [markdown]
# ### **Outlier Detection**

# %%
"sessions_per_week","avg_session_duration_min","daily_active_minutes","feature_clicks_per_session","notifications_opened_per_week","in_app_search_count","crash_events_last_30_days","support_tickets_raised","ads_clicked_last_30_days","content_downloads","social_shares","engagement_score",

# %% [markdown]
# **sessions_per_week**

# %%
px.box(data_frame=app_df,x="sessions_per_week")

# %%
Q1 = np.percentile(app_df['sessions_per_week'],25)
Q2 = np.percentile(app_df['sessions_per_week'],50)
Q3 = np.percentile(app_df['sessions_per_week'],75)
IQR = Q3 - Q1

upper_bound = Q3 + (1.5*IQR)
lower_bound = Q1 - (1.5*IQR)
print(lower_bound)
print(upper_bound)

# %%
# app_df = app_df[(app_df['sessions_per_week']<=upper_bound) & (app_df['sessions_per_week']>=lower_bound)]

# %%
app_df['sessions_per_week']=np.clip(app_df['sessions_per_week'],lower_bound, upper_bound)

# %% [markdown]
# **avg_session_duration_min**

# %%
px.box(data_frame=app_df,x="avg_session_duration_min")

# %%
Q1 = np.percentile(app_df['avg_session_duration_min'],25)
Q2 = np.percentile(app_df['avg_session_duration_min'],50)
Q3 = np.percentile(app_df['avg_session_duration_min'],75)
IQR = Q3 - Q1

upper_bound = Q3 + (1.5*IQR)
lower_bound = Q1 - (1.5*IQR)
print(lower_bound)
print(upper_bound)

# %%
# app_df = app_df[(app_df['avg_session_duration_min']<=upper_bound) & (app_df['avg_session_duration_min']>=lower_bound)]

# %%
app_df['avg_session_duration_min']=np.clip(app_df['avg_session_duration_min'],lower_bound, upper_bound)

# %% [markdown]
# **daily_active_minutes**

# %%
px.box(data_frame=app_df,x="daily_active_minutes")

# %%
Q1 = np.percentile(app_df['daily_active_minutes'],25)
Q2 = np.percentile(app_df['daily_active_minutes'],50)
Q3 = np.percentile(app_df['daily_active_minutes'],75)
IQR = Q3 - Q1

upper_bound = Q3 + (1.5*IQR)
lower_bound = Q1 - (1.5*IQR)
print(lower_bound)
print(upper_bound)

# %%
app_df = app_df[(app_df['daily_active_minutes']<=upper_bound) & (app_df['daily_active_minutes']>=lower_bound)]

# %%
# app_df['daily_active_minutes']=np.clip(app_df['daily_active_minutes'],lower_bound, upper_bound)

# %% [markdown]
# **feature_clicks_per_session**

# %%
px.box(data_frame=app_df,x="feature_clicks_per_session")

# %%
Q1 = np.percentile(app_df['feature_clicks_per_session'],25)
Q2 = np.percentile(app_df['feature_clicks_per_session'],50)
Q3 = np.percentile(app_df['feature_clicks_per_session'],75)
IQR = Q3 - Q1

upper_bound = Q3 + (1.5*IQR)
lower_bound = Q1 - (1.5*IQR)
print(lower_bound)
print(upper_bound)

# %%
# app_df = app_df[(app_df['feature_clicks_per_session']<=upper_bound) & (app_df['feature_clicks_per_session']>=lower_bound)]

# %%
app_df['feature_clicks_per_session']=np.clip(app_df['feature_clicks_per_session'],lower_bound, upper_bound)

# %% [markdown]
# **notifications_opened_per_week**

# %%
px.box(data_frame=app_df,x="notifications_opened_per_week")

# %%
Q1 = np.percentile(app_df['notifications_opened_per_week'],25)
Q2 = np.percentile(app_df['notifications_opened_per_week'],50)
Q3 = np.percentile(app_df['notifications_opened_per_week'],75)
IQR = Q3 - Q1

upper_bound = Q3 + (1.5*IQR)
lower_bound = Q1 - (1.5*IQR)
print(lower_bound)
print(upper_bound)

# %%
# app_df = app_df[(app_df['notifications_opened_per_week']<=upper_bound) & (app_df['notifications_opened_per_week']>=lower_bound)]

# %%
app_df['notifications_opened_per_week']=np.clip(app_df['notifications_opened_per_week'],lower_bound, upper_bound)

# %% [markdown]
# **in_app_search_count**

# %%
px.box(data_frame=app_df,x="in_app_search_count")

# %%
Q1 = np.percentile(app_df['in_app_search_count'],25)
Q2 = np.percentile(app_df['in_app_search_count'],50)
Q3 = np.percentile(app_df['in_app_search_count'],75)
IQR = Q3 - Q1

upper_bound = Q3 + (1.5*IQR)
lower_bound = Q1 - (1.5*IQR)
print(lower_bound)
print(upper_bound)

# %%
# app_df = app_df[(app_df['in_app_search_count']<=upper_bound) & (app_df['in_app_search_count']>=lower_bound)]

# %%
app_df['in_app_search_count']=np.clip(app_df['in_app_search_count'],lower_bound, upper_bound)

# %% [markdown]
# **crash_events_last_30_days**

# %%
px.box(data_frame=app_df,x="crash_events_last_30_days")

# %%
Q1 = np.percentile(app_df['crash_events_last_30_days'],25)
Q2 = np.percentile(app_df['crash_events_last_30_days'],50)
Q3 = np.percentile(app_df['crash_events_last_30_days'],75)
IQR = Q3 - Q1

upper_bound = Q3 + (1.5*IQR)
lower_bound = Q1 - (1.5*IQR)
print(lower_bound)
print(upper_bound)

# %%
# app_df = app_df[(app_df['crash_events_last_30_days']<=upper_bound) & (app_df['crash_events_last_30_days']>=lower_bound)]

# %%
app_df['crash_events_last_30_days']=np.clip(app_df['crash_events_last_30_days'],lower_bound, upper_bound)

# %% [markdown]
# **support_tickets_raised**

# %%
px.box(data_frame=app_df,x="support_tickets_raised")

# %%
Q1 = np.percentile(app_df['support_tickets_raised'],25)
Q2 = np.percentile(app_df['support_tickets_raised'],50)
Q3 = np.percentile(app_df['support_tickets_raised'],75)
IQR = Q3 - Q1

upper_bound = Q3 + (1.5*IQR)
lower_bound = Q1 - (1.5*IQR)
print(lower_bound)
print(upper_bound)

# %%
# app_df = app_df[(app_df['support_tickets_raised']<=upper_bound) & (app_df['support_tickets_raised']>=lower_bound)]

# %%
app_df['support_tickets_raised']=np.clip(app_df['support_tickets_raised'],lower_bound, upper_bound)

# %% [markdown]
# **ads_clicked_last_30_days**

# %%
px.box(data_frame=app_df,x="ads_clicked_last_30_days")

# %%
Q1 = np.percentile(app_df['ads_clicked_last_30_days'],25)
Q2 = np.percentile(app_df['ads_clicked_last_30_days'],50)
Q3 = np.percentile(app_df['ads_clicked_last_30_days'],75)
IQR = Q3 - Q1

upper_bound = Q3 + (1.5*IQR)
lower_bound = Q1 - (1.5*IQR)
print(lower_bound)
print(upper_bound)

# %%
# app_df = app_df[(app_df['ads_clicked_last_30_days']<=upper_bound) & (app_df['ads_clicked_last_30_days']>=lower_bound)]

# %%
app_df['ads_clicked_last_30_days']=np.clip(app_df['ads_clicked_last_30_days'],lower_bound, upper_bound)

# %% [markdown]
# **content_downloads**

# %%
px.box(data_frame=app_df,x="content_downloads")

# %%
Q1 = np.percentile(app_df['content_downloads'],25)
Q2 = np.percentile(app_df['content_downloads'],50)
Q3 = np.percentile(app_df['content_downloads'],75)
IQR = Q3 - Q1

upper_bound = Q3 + (1.5*IQR)
lower_bound = Q1 - (1.5*IQR)
print(lower_bound)
print(upper_bound)

# %%
# app_df = app_df[(app_df['content_downloads']<=upper_bound) & (app_df['content_downloads']>=lower_bound)]

# %%
app_df['content_downloads']=np.clip(app_df['content_downloads'],lower_bound, upper_bound)

# %% [markdown]
# **social_shares**

# %%
px.box(data_frame=app_df,x="social_shares")

# %%
Q1 = np.percentile(app_df['social_shares'],25)
Q2 = np.percentile(app_df['social_shares'],50)
Q3 = np.percentile(app_df['social_shares'],75)
IQR = Q3 - Q1

upper_bound = Q3 + (1.5*IQR)
lower_bound = Q1 - (1.5*IQR)
print(lower_bound)
print(upper_bound)

# %%
# app_df = app_df[(app_df['social_shares']<=upper_bound) & (app_df['social_shares']>=lower_bound)]

# %%
app_df['social_shares']=np.clip(app_df['social_shares'],lower_bound, upper_bound)

# %% [markdown]
# **engagement_score**

# %%
px.box(data_frame=app_df,x="engagement_score")

# %%
Q1 = np.percentile(app_df['engagement_score'],25)
Q2 = np.percentile(app_df['engagement_score'],50)
Q3 = np.percentile(app_df['engagement_score'],75)
IQR = Q3 - Q1

upper_bound = Q3 + (1.5*IQR)
lower_bound = Q1 - (1.5*IQR)
print(lower_bound)
print(upper_bound)

# %%
app_df = app_df[(app_df['engagement_score']<=upper_bound) & (app_df['engagement_score']>=lower_bound)]

# %%
# app_df['engagement_score']=np.clip(app_df['engagement_score'],lower_bound, upper_bound)

# %%
app_df.select_dtypes("number").columns

# %%
app_df.select_dtypes("object").columns

# %%
app_df['marketing_source'].value_counts()

# %%
app_df.head()

# %%
app_df[["notifications_opened_per_week","in_app_search_count","pages_viewed_per_session","crash_events_last_30_days","support_tickets_raised"]].head()

# %%
app_df.info()

# %%
app_df['crash_events_last_30_days'].value_counts()

# %%
app_df['device_type'].value_counts()

# %%
app_df['social_shares'].value_counts()

# %%
app_df.reset_index(drop=True, inplace=True)

# %%
app_df.info()

# %% [markdown]
# ## **Encoding**

# %%
app_df_encode = app_df.copy()

# %%
app_df_encode.select_dtypes('object').columns

# %%
app_df_encode['gender'].value_counts()

# %%
# app_df_encode = pd.get_dummies(
#     app_df_encode,
#     columns=["gender"],
#     drop_first=True,
#     dtype=int
# )

# %%
app_df['country'].value_counts()

# %%
# app_df_encode = pd.get_dummies(
#     app_df_encode,
#     columns=["country"],
#     drop_first=True,
#     dtype=int
# )

# %%
app_df_encode['device_type'].value_counts()

# %%
# app_df_encode = pd.get_dummies(
#     app_df_encode,
#     columns=["device_type"],
#     drop_first=True,
#     dtype=int
# )

# %%
app_df_encode['subscription_type'].value_counts()

# %%
# app_df_encode['subscription_type'] = app_df_encode["subscription_type"].map({
#     "Free":0,
#     "Basic":1,
#     "Premium":2
# })

# %%
app_df_encode['marketing_source'].value_counts()

# %%
# app_df_encode = pd.get_dummies(
#     app_df_encode,
#     columns=["marketing_source"],
#     drop_first=True,
#     dtype=int
# )

# %%
app_df_encode.info()

# %% [markdown]
# ## **K-Means**

# %%
# Fix 1: Use only the 3 strongest behavioral signals
best_cols = [
    'engagement_score',
    'churn_risk_score',
    'daily_active_minutes',
]
X = app_df[best_cols].copy()

# %%
# Fix 2: Scale first
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# # Fix 3: Apply PCA to compress and remove noise
# pca = PCA(n_components=0.90)
# X_pca = pca.fit_transform(X_scaled)
# print(f"Variance retained: {sum(pca.explained_variance_ratio_)*100:.1f}%")

# %%
# ELBOW METHOD — Finding the right number of clusters
# WCSS = how spread out points are within each cluster (lower = tighter clusters)

wcss = []
K_values = range(1, 10)

for k in K_values:
    model = KMeans(n_clusters=k,random_state=42)
    model.fit(X_scaled)
    wcss.append(model.inertia_)   # inertia = WCSS

# Plot the elbow
plt.figure(figsize=(10, 5))
plt.plot(K_values, wcss, 'o-', color='#3498db', linewidth=3, markersize=10, markerfacecolor='white',
         markeredgewidth=2, markeredgecolor='#3498db')



plt.title('🦾 Elbow Method — How Many Clusters?', fontsize=14, fontweight='bold')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('WCSS (Total cluster tightness)')
plt.xticks(K_values)
plt.legend(fontsize=12)
plt.grid(True, alpha=0.4)
plt.tight_layout()
plt.show()

# %%
# Try different k values on the PCA output
for k in range(2, 5):
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = km.fit_predict(X_scaled)
    score = silhouette_score(X_scaled, labels)
    print(f"k={k}, Silhouette Score={score:.4f}")

# %%
km = KMeans(n_clusters=4, random_state=42, n_init=10)
labels = km.fit_predict(X_scaled)
score = silhouette_score(X_scaled, labels)
print(f"Silhouette Score={score:.4f}")

# %%
# Step 1: Get the TRUE cluster profile (average per cluster)
app_df['cluster'] = labels

profile = app_df.groupby('cluster')[best_cols].mean().round(2)
print(profile)

# %%
cluster_names = {
    0: 'At Risk Users',      # high engagement BUT high churn - about to leave
    1: 'High Churn Risk',    # low engagement + high churn - already disengaged
    2: 'Casual Users',       # decent engagement, low churn, less daily use
    3: 'Loyal Active Users'  # most daily active + lowest churn - your best users
}

app_df['segment'] = app_df['cluster'].map(cluster_names)
print(app_df['segment'].value_counts())

# %%
app_df['segment'].value_counts()

# %%
best_cols = [
    'engagement_score',
    'churn_risk_score',
    'daily_active_minutes','segment'
]
app_df[best_cols].head(30)
